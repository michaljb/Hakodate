# %%
import get_decreasing_data
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as cnc

# %matplotlib inline

# %%
def plot_series_as_func_of_time(col):
    y = np.array(col)
    x = x = np.arange(0,y.shape[0])/2
    plt.plot(x,y)
    return x, y

# %%
def mypolyfit_y(x, y, deg):
    a = np.polyfit(x, y, deg)
    yy=0
    for j in range(len(a)):
        yy += a[-j-1]*x**j
    return a, yy

# %%
df = get_decreasing_data.get_decreasing_df()
# Out:
# /home/ubuntu/michal/Hakodate/get_decreasing_data.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data["start_decrease"] = first_index
# /home/ubuntu/michal/Hakodate/get_decreasing_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data["end_data"] = last_index

# %%
df["posZ"]
# Out:
# 1     [8076.75484631, 8075.48815853, 8065.34459174, ...
# 2     [7804.59700371, 7796.36193989, 7774.98015624, ...
# 3     [18663.7080762, 18658.6674275, 18649.3245972, ...
# 6     [1841.89589425, 1721.70532429, 1595.39894829, ...
# 8     [22755.0077447, 22730.722812, 22705.4872449, 2...
# 10    [2298.32420223, 2251.69924707, 2201.4720581, 2...
# Name: posZ, dtype: object

# %%
k=4

# %%
_ = plot_series_as_func_of_time(df["posZ"].iloc[k])

# %%
x, y = plot_series_as_func_of_time(df["velZ"].iloc[k])

# %%
a, yy = mypolyfit_y(x, y, 2)

# %%
yy = np.array([y, yy]).T

# %%
plt.plot(x, yy)
# Out:
# [<matplotlib.lines.Line2D at 0x7f3a9faddb00>,
#  <matplotlib.lines.Line2D at 0x7f3a9faddb70>]
